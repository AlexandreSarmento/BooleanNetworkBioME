# %% [markdown]
# <a href="https://colab.research.google.com/github/AlexandreSarmento/BooleanNetworkBioME/blob/master/Supplemental%20Materia/drawing_network.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip3 install pip --upgrade
# !pip3 install git+https://github.com/hklarner/pyboolnet@3.0.5

# %%
# !apt install clasp
# !apt install gringo

# %%
# !pip3 install networkx
# !apt install graphviz
# !apt install imagemagick

# %%
# !apt-get install libreadline6:i386
# !apt-get install libreadline-dev
# !cd /lib/x86_64-linux-gnu ; sudo ln -s libreadline.so.7.0 libreadline.so.6

# %%
import pyboolnet
from IPython.display import Image
from pyboolnet import file_exchange,interaction_graphs

# %%
from google.colab import files
uploaded = files.upload()

# %%
with open('/content/TBN_Zhou.bn','r') as file:
  bnet = file.read()

primes = pyboolnet.file_exchange.bnet2primes(bnet)
pyboolnet.interaction_graphs.create_image(primes,"network_graph.pdf")
pyboolnet.interaction_graphs.create_image(primes,"network_graph.jpg")

# %%
w = 800
h = w
Image('network_graph.jpg')
Image("network_graph.jpg", width = w, height = h)
